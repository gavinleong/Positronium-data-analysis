# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.optimize import curve_fit # we're importing just this one function from scipy.optimize
from scipy.interpolate import UnivariateSpline

# %% [markdown]
# 161020_MCA_13-14psi_delay_265(5)ns (the first one we did)

# %%
plt.figure(num=None, figsize=(15, 8), dpi=80, facecolor='w', edgecolor='k')

ydata = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161020_MCA_13-14psi_delay_265(5)ns.csv', comments = '#', unpack = True)
xdata = np.arange(0,2048)

index = [item for item in range(len(ydata)) if ydata[item] == 0]
ydata = [i for j, i in enumerate(ydata) if j not in index]
xdata = [i for j, i in enumerate(xdata) if j not in index]

print(np.max(ydata))

x_index = np.arange(len(xdata))


for i in x_index:
    if ydata[i] == np.max(ydata):
        start = i
        x0 = xdata[start]
print(x0)

plt.semilogy(xdata,ydata,'b.')
# Out:
# 344421.0
# 561

# %% [markdown]
# BEFORE 71 PSI MEASUREMENT

# %%
plt.figure(num=None, figsize=(15, 8), dpi=80, facecolor='w', edgecolor='k')

ydata1 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161027_MCA_14psi_delay115(2.5)ns.csv', comments = '#', unpack = True)
ydata2 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161027_MCA_14psi_delay162.5(2.5)ns.csv', comments = '#', unpack = True)
ydata3 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161027_MCA_14psi_delay265(5)ns.csv', comments = '#', unpack = True)
ydata4 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161027_MCA_14psi_delay540(10)ns.csv', comments = '#', unpack = True)

xdata = np.arange(1,2049) - 0.5


print(np.max(ydata1))
print(np.max(ydata2))
print(np.max(ydata3))
print(np.max(ydata4))

x_index = np.arange(len(xdata))

for i in x_index:
    if ydata1[i] == np.max(ydata1):
        start = i
        x01 = xdata[start]
        
for i in x_index:
    if ydata2[i] == np.max(ydata2):
        start = i
        x02 = xdata[start]
        
for i in x_index:
    if ydata3[i] == np.max(ydata3):
        start = i
        x03 = xdata[start]
        
for i in x_index:
    if ydata4[i] == np.max(ydata4):
        start = i
        x04 = xdata[start]

print(x01)
print(x02)
print(x03)
print(x04)

plt.figure(0)

plt.semilogy(xdata,ydata1,'b.')
plt.semilogy(xdata,ydata2,'r.')
plt.semilogy(xdata,ydata3,'g.')
plt.semilogy(xdata,ydata4,'k.')

plt.figure(1)

x0 = np.array([x01, x02, x03, x04])
y0 = np.array([115,162.5,265,540])
y0_err = np.array([2.5,2.5,5,10])
x0_err = np.array([0.5,0.5,0.5,0.5])

plt.errorbar(x0,y0,xerr = x0_err, yerr = y0_err, fmt='k.')

def line(x, m, c):
    '''Definition of straight line with slope m and intercept c'''
    y = m*x + c
    return y

m = 1000 / 2048.0
c = 0
print ('m', m)
guess = [m, c]

popt, pcov = curve_fit(line, x0, y0, p0=guess, sigma = y0_err)

slope = popt[0]
slope_err = np.sqrt(np.diag(pcov)[0])
intercept = popt[1]
intercept_err = np.sqrt(np.diag(pcov)[1])

print("error on slope", slope_err)
print("error on intercept", intercept_err)
print("slope", slope)
print("intercept", intercept)

x = np.linspace(0, 2048, 10000)
y = line(x, slope, intercept)

plt.plot(x,y, 'r-')

TAC_range = line(2048, slope, intercept)
TAC_range_err = 2048*slope_err + intercept_err
print (TAC_range)
print (TAC_range_err)
# Out:
# 62580.0
# 61454.0
# 55893.0
# 63816.0
# 249.5
# 348.5
# 560.5
# 1135.5
# ('m', 0.48828125)
# ('error on slope', 0.00098667604001703582)
# ('error on intercept', 0.37990196357180112)
# ('slope', 0.48040491815066377)
# ('intercept', -4.840050499906785)
# 979.029221873
# 2.40061449353

# %% [markdown]
# after 71psi measurement

# %%
plt.figure(num=None, figsize=(15, 8), dpi=80, facecolor='w', edgecolor='k')

ydata1 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161028_MCA_71psi_delay115(2.5)ns.csv', comments = '#', unpack = True)
ydata2 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161028_MCA_71psi_delay162.5(2.5)ns.csv', comments = '#', unpack = True)
ydata3 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161028_MCA_71psi_delay265(5)ns.csv', comments = '#', unpack = True)
ydata4 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161028_MCA_71psi_delay540(10)ns.csv', comments = '#', unpack = True)

xdata = np.arange(1,2049) - 0.5


print(np.max(ydata1))
print(np.max(ydata2))
print(np.max(ydata3))
print(np.max(ydata4))

x_index = np.arange(len(xdata))

for i in x_index:
    if ydata1[i] == np.max(ydata1):
        start = i
        x01 = xdata[start]
        
for i in x_index:
    if ydata2[i] == np.max(ydata2):
        start = i
        x02 = xdata[start]
        
for i in x_index:
    if ydata3[i] == np.max(ydata3):
        start = i
        x03 = xdata[start]
        
for i in x_index:
    if ydata4[i] == np.max(ydata4):
        start = i
        x04 = xdata[start]

print(x01)
print(x02)
print(x03)
print(x04)

plt.figure(0)

plt.semilogy(xdata,ydata1,'b.')
plt.semilogy(xdata,ydata2,'r.')
plt.semilogy(xdata,ydata3,'g.')
plt.semilogy(xdata,ydata4,'k.')

plt.figure(1)

x0 = np.array([x01, x02, x03, x04])
y0 = np.array([115,162.5,265,540])
y0_err = np.array([2.5,2.5,5,10])
x0_err = np.array([0.5,0.5,0.5,0.5])

plt.errorbar(x0,y0,xerr = x0_err, yerr = y0_err, fmt='k.')

def line(x, m, c):
    '''Definition of straight line with slope m and intercept c'''
    y = m*x + c
    return y

m = 1000 / 2048.0
c = 0
print ('m', m)
guess = [m, c]

popt, pcov = curve_fit(line, x0, y0, p0=guess, sigma = y0_err)

slope = popt[0]
slope_err = np.sqrt(np.diag(pcov)[0])
intercept = popt[1]
intercept_err = np.sqrt(np.diag(pcov)[1])

print("error on slope", slope_err)
print("error on intercept", intercept_err)
print("slope", slope)
print("intercept", intercept)

x = np.linspace(0, 2048, 10000)
y = line(x, slope, intercept)

plt.plot(x,y, 'r-')

TAC_range = line(2048, slope, intercept)
TAC_range_err = 2048*slope_err + intercept_err
print (TAC_range)
print (TAC_range_err)
# Out:
# 19232.0
# 15262.0
# 17319.0
# 36167.0
# 250.5
# 348.5
# 560.5
# 1136.5
# ('m', 0.48828125)
# ('error on slope', 0.0015825697687058104)
# ('error on intercept', 0.60991054592586103)
# ('slope', 0.48081228136351123)
# ('intercept', -5.2034917300245649)
# 979.500060502
# 3.85101343224

# %% [markdown]
# BEFORE 52psi measurement

# %%
plt.figure(num=None, figsize=(15, 8), dpi=80, facecolor='w', edgecolor='k')

ydata1 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161103_MCA_23psi_delay115.0(2.5)ns_range500ns.csv', comments = '#', unpack = True)
ydata2 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161103_MCA_23psi_delay162.5(2.5)ns_range500ns.csv', comments = '#', unpack = True)
ydata3 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161103_MCA_23psi_delay265(5)ns_range500ns.csv', comments = '#', unpack = True)
ydata4 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161103_MCA_23psi_delay410(5)ns_range500ns.csv', comments = '#', unpack = True)

xdata = np.arange(1,2049) - 0.5


print(np.max(ydata1))
print(np.max(ydata2))
print(np.max(ydata3))
print(np.max(ydata4))

x_index = np.arange(len(xdata))

for i in x_index:
    if ydata1[i] == np.max(ydata1):
        start = i
        x01 = xdata[start]
        
for i in x_index:
    if ydata2[i] == np.max(ydata2):
        start = i
        x02 = xdata[start]
        
for i in x_index:
    if ydata3[i] == np.max(ydata3):
        start = i
        x03 = xdata[start]
        
for i in x_index:
    if ydata4[i] == np.max(ydata4):
        start = i
        x04 = xdata[start]

print(x01)
print(x02)
print(x03)
print(x04)

plt.figure(0)

plt.semilogy(xdata,ydata1,'b.')
plt.semilogy(xdata,ydata2,'r.')
plt.semilogy(xdata,ydata3,'g.')
plt.semilogy(xdata,ydata4,'k.')

plt.figure(1)

x0 = np.array([x01, x02, x03, x04])
y0 = np.array([115,162.5,265,410])
y0_err = np.array([2.5,2.5,5,5])
x0_err = np.array([0.5,0.5,0.5,0.5])

plt.errorbar(x0,y0,xerr = x0_err, yerr = y0_err, fmt='k.')

def line(x, m, c):
    '''Definition of straight line with slope m and intercept c'''
    y = m*x + c
    return y

m = 500 / 2048.0
c = 0
print ('m', m)
guess = [m, c]

popt, pcov = curve_fit(line, x0, y0, p0=guess, sigma = y0_err)

slope = popt[0]
slope_err = np.sqrt(np.diag(pcov)[0])
intercept = popt[1]
intercept_err = np.sqrt(np.diag(pcov)[1])

print("error on slope", slope_err)
print("error on intercept", intercept_err)
print("slope", slope)
print("intercept", intercept)

x = np.linspace(0, 2048, 10000)
y = line(x, slope, intercept)

plt.plot(x,y, 'r-')

TAC_range = line(2048, slope, intercept)
TAC_range_err = 2048*slope_err + intercept_err
print (TAC_range)
print (TAC_range_err)
# Out:
# 7906.0
# 8201.0
# 8492.0
# 7215.0
# 505.5
# 704.5
# 1130.5
# 1761.5
# ('m', 0.244140625)
# ('error on slope', 0.0016905824106767762)
# ('error on intercept', 1.4531452226892507)
# ('slope', 0.23553651953962171)
# ('intercept', -3.6168368271653226)
# 478.76195519
# 4.91545799976

# %% [markdown]
# AFTER 52psi measurement

# %%
plt.figure(num=None, figsize=(15, 8), dpi=80, facecolor='w', edgecolor='k')

ydata1 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161104_MCA_52psi_delay115.0(2.5)ns_range500ns.csv', comments = '#', unpack = True)
ydata2 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161104_MCA_52psi_delay162.5(2.5)ns_range500ns.csv', comments = '#', unpack = True)
ydata3 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161104_MCA_52psi_delay265(5)ns_range500ns.csv', comments = '#', unpack = True)
ydata4 = np.loadtxt('N:/Lab 3/Positronium/MCA data analysis/161104_MCA_52psi_delay410(5)ns_range500ns.csv', comments = '#', unpack = True)

xdata = np.arange(1,2049) - 0.5


print(np.max(ydata1))
print(np.max(ydata2))
print(np.max(ydata3))
print(np.max(ydata4))

x_index = np.arange(len(xdata))

for i in x_index:
    if ydata1[i] == np.max(ydata1):
        start = i
        x01 = xdata[start]
        
for i in x_index:
    if ydata2[i] == np.max(ydata2):
        start = i
        x02 = xdata[start]
        
for i in x_index:
    if ydata3[i] == np.max(ydata3):
        start = i
        x03 = xdata[start]
        
for i in x_index:
    if ydata4[i] == np.max(ydata4):
        start = i
        x04 = xdata[start]

print(x01)
print(x02)
print(x03)
print(x04)

plt.figure(0)

plt.semilogy(xdata,ydata1,'b.')
plt.semilogy(xdata,ydata2,'r.')
plt.semilogy(xdata,ydata3,'g.')
plt.semilogy(xdata,ydata4,'k.')

plt.figure(1)

x0 = np.array([x01, x02, x03, x04])
y0 = np.array([115,162.5,265,410])
y0_err = np.array([2.5,2.5,5,5])
x0_err = np.array([0.5,0.5,0.5,0.5])

plt.errorbar(x0,y0,xerr = x0_err, yerr = y0_err, fmt='k.')

def line(x, m, c):
    '''Definition of straight line with slope m and intercept c'''
    y = m*x + c
    return y

m = 500 / 2048.0
c = 0
print ('m', m)
guess = [m, c]

popt, pcov = curve_fit(line, x0, y0, p0=guess, sigma = y0_err)

slope = popt[0]
slope_err = np.sqrt(np.diag(pcov)[0])
intercept = popt[1]
intercept_err = np.sqrt(np.diag(pcov)[1])

print("error on slope", slope_err)
print("error on intercept", intercept_err)
print("slope", slope)
print("intercept", intercept)

x = np.linspace(0, 2048, 10000)
y = line(x, slope, intercept)

plt.plot(x,y, 'r-')

TAC_range = line(2048, slope, intercept)
TAC_range_err = 2048*slope_err + intercept_err
print (TAC_range)
print (TAC_range_err)
# Out:
# 13939.0
# 12785.0
# 14537.0
# 11993.0
# 505.5
# 703.5
# 1130.5
# 1760.5
# ('m', 0.244140625)
# ('error on slope', 0.0016763717438264309)
# ('error on intercept', 1.4400374896617345)
# ('slope', 0.23565581066663177)
# ('intercept', -3.5912447883840506)
# 479.031855457
# 4.87324682102
